# %%
# Forestry Data Tracker (FDT) - Jupyter Demo
# Bismillahir Rahmanir Rahim

import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display, Markdown
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import json

# --- Tree Data Dictionary ---
tree_data = {
    "Oak": {
        "Temperature": "15–25°C",
        "Humidity": "60–80%",
        "Rainfall": "500–700 mm/year",
        "GrowthRate": [0, 0.5, 1, 2, 3, 4, 5, 6, 7, 8],
        "Pests": ["Aphids", "Oak Moth", "Bark Beetles"]
    },
    "Pine": {
        "Temperature": "5–20°C",
        "Humidity": "50–70%",
        "Rainfall": "400–600 mm/year",
        "GrowthRate": [0, 0.6, 1.2, 1.8, 2.4, 3, 3.6, 4.2, 4.8, 5.4],
        "Pests": ["Pine Beetles", "Pine Weevils", "Aphids"]
    },
    "Maple": {
        "Temperature": "10–20°C",
        "Humidity": "50–70%",
        "Rainfall": "600–800 mm/year",
        "GrowthRate": [0, 0.4, 0.8, 1.5, 2.3, 3, 3.7, 4.5, 5.2, 6],
        "Pests": ["Maple Borers", "Leaf Spot", "Aphids"]
    },
    "Olive": {
        "Temperature": "10–30°C",
        "Humidity": "40–60%",
        "Rainfall": "300–600 mm/year",
        "GrowthRate": [0, 0.2, 0.5, 0.9, 1.3, 1.8, 2.2, 2.5, 2.7, 3.0],
        "Pests": ["Olive Fruit Fly", "Verticillium Wilt", "Olive Knot Disease"]
    }
}

# --- User Selection ---
species = "Olive"  # change this value to test other trees (e.g. "Oak", "Pine", "Maple")
data = tree_data[species]

# --- Display Tree Information ---
display(Markdown(f"## 🌳 {species} Tree Data"))
display(Markdown(f"""
**Temperature Range:** {data['Temperature']}  
**Humidity Range:** {data['Humidity']}  
**Rainfall Range:** {data['Rainfall']}  
**Common Pests:** {', '.join(data['Pests'])}
"""))

# --- Plot Growth Chart ---
plt.figure(figsize=(8,5))
years = list(range(0, len(data['GrowthRate'])))
plt.plot(years, data["GrowthRate"], marker='o', linestyle='-', linewidth=2)
plt.title(f"{species} Tree Growth Over Time")
plt.xlabel("Years")
plt.ylabel("Height (m)")
plt.grid(True)
plt.show()

# --- Comparative Table (optional) ---
comparison_df = pd.DataFrame({
    "Species": list(tree_data.keys()),
    "Temperature Range": [tree_data[t]["Temperature"] for t in tree_data],
    "Humidity Range": [tree_data[t]["Humidity"] for t in tree_data],
    "Rainfall Range": [tree_data[t]["Rainfall"] for t in tree_data]
})
display(Markdown("### 🌿 Environmental Suitability Comparison"))
display(comparison_df)
# Out:
# ## 🌳 Olive Tree Data
# **Temperature Range:** 10–30°C
# **Humidity Range:** 40–60%
# **Rainfall Range:** 300–600 mm/year
# **Common Pests:** Olive Fruit Fly, Verticillium Wilt, Olive Knot Disease
# ### 🌿 Environmental Suitability Comparison
#   Species Temperature Range Humidity Range   Rainfall Range
# 0     Oak           15–25°C         60–80%  500–700 mm/year
# 1    Pine            5–20°C         50–70%  400–600 mm/year
# 2   Maple           10–20°C         50–70%  600–800 mm/year
# 3   Olive           10–30°C         40–60%  300–600 mm/year

# %%
# Define integrated dataset for crops + animals in water-harvesting systems
data = {
    "Region": [
        # Palestine
        "Palestine", "Palestine", "Palestine", "Palestine",
        # Sudan
        "Sudan", "Sudan", "Sudan", "Sudan",
        # Bengal/Myanmar
        "Bengal/Myanmar", "Bengal/Myanmar", "Bengal/Myanmar", "Bengal/Myanmar",
        # Sahel
        "Sahel", "Sahel", "Sahel", "Sahel",
        # Swahili Coast / Somalia
        "Swahili/Somalia", "Swahili/Somalia", "Swahili/Somalia", "Swahili/Somalia"
    ],
    "Species": [
        # Palestine
        "Olive (Olea europaea)",
        "Chickpea (Cicer arietinum)",
        "Moringa peregrina",
        "Goat (Capra hircus)",
        # Sudan
        "Sorghum (Sorghum bicolor)",
        "Baobab (Adansonia digitata)",
        "Groundnut (Arachis hypogaea)",
        "Camel (Camelus dromedarius)",
        # Bengal/Myanmar
        "Rice (Oryza sativa, drought-tolerant landrace)",
        "Pigeon Pea (Cajanus cajan)",
        "Bottle Gourd (Lagenaria siceraria)",
        "Tilapia Fish (Oreochromis niloticus)",
        # Sahel
        "Millet (Pennisetum glaucum)",
        "Cowpea (Vigna unguiculata)",
        "Prickly Pear Cactus (Opuntia ficus-indica)",
        "Sheep (Ovis aries)",
        # Swahili Coast / Somalia
        "Cassava (Manihot esculenta)",
        "Sesame (Sesamum indicum)",
        "Moringa oleifera",
        "Zebu Cattle (Bos indicus)"
    ],
    "Function": [
        # Palestine
        "Perennial oil/tree crop; erosion control; shade & moisture buffer",
        "Nitrogen-fixing pulse; dryland compatible; low-input",
        "Edible leaves; water filtration; drought resilient",
        "Browsers that recycle shrubs and olive waste into manure; hardy on dry slopes",
        # Sudan
        "Main cereal; ridge-compatible; residue for fodder and mulch",
        "Tree for shade, leaves, and vitamin-rich fruit; water retention support",
        "Legume improving soil fertility; compatible with tied-ridge sorghum systems",
        "Manure source; used for milk and dryland traction; minimal water footprint",
        # Bengal/Myanmar
        "Main wetland crop; adapted to monsoon; water synergy with fish ponds",
        "Legume for intercropping with rice and maize; nitrogen fixer",
        "Climbing crop for vertical integration; water-efficient",
        "Used in integrated aquaculture; effluent enriches soil and crops",
        # Sahel
        "Staple grain for sandy soils; deep-rooted drought tolerance",
        "Legume groundcover that retains soil moisture and nitrogen",
        "Cactus used as live fence, fodder, and emergency water/food",
        "Grazing and manure cycling for nutrient input; drought-adapted breeds",
        # Swahili Coast / Somalia
        "Drought-tolerant staple; grows in sandy coastal soils",
        "Oilseed with low water demand; adds diversity and income",
        "Tree with edible pods and leaves; greywater tolerant",
        "Cattle used for mixed farming; manure enriches ridged plots"
    ],
    "System_Role": [
        # Palestine
        "Base layer for dry permaculture terraces",
        "Soil improvement & protein crop",
        "Multi-purpose tree; biofilter & food",
        "Livestock manure & browsing for ecosystem cycling",
        # Sudan
        "Staple crop for ridge moisture capture",
        "Shade & nutrient stabilizer tree",
        "Soil nitrogen addition & intercrop stabilizer",
        "Low water-use livestock for manure input",
        # Bengal/Myanmar
        "Aquatic staple linked to fish systems",
        "Nitrogen fixer for rainfed plots",
        "Vertical space & humidity regulator",
        "Water-soil nutrient loop; mineral enrichment",
        # Sahel
        "Dryland grain integrated with runoff ridges",
        "Legume for sand stabilization & fertility",
        "Fodder, water retention & bio-fence",
        "Organic fertilizer and animal traction",
        # Swahili Coast / Somalia
        "Root crop with high caloric yield under stress",
        "Cash crop for oil and pollinator support",
        "Drought tree for nutrient retention and shade",
        "Integrated livestock nutrient return system"
    ]
}

df = pd.DataFrame(data)

# Display dataset
print("Integrated Agroecological Dataset for In-Situ Systems:")
df
# Out:
# Integrated Agroecological Dataset for In-Situ Systems:
#              Region                                         Species  \
# 0         Palestine                           Olive (Olea europaea)
# 1         Palestine                      Chickpea (Cicer arietinum)
# 2         Palestine                               Moringa peregrina
# 3         Palestine                             Goat (Capra hircus)
# 4             Sudan                       Sorghum (Sorghum bicolor)
# 5             Sudan                     Baobab (Adansonia digitata)
# 6             Sudan                    Groundnut (Arachis hypogaea)
# 7             Sudan                     Camel (Camelus dromedarius)
# 8    Bengal/Myanmar  Rice (Oryza sativa, drought-tolerant landrace)
# 9    Bengal/Myanmar                      Pigeon Pea (Cajanus cajan)
# 10   Bengal/Myanmar              Bottle Gourd (Lagenaria siceraria)
# 11   Bengal/Myanmar            Tilapia Fish (Oreochromis niloticus)
# ...

# %%
# Define integrated dataset for crops + animals in water-harvesting systems
data = {
    "Region": [
        # Palestine
        "Palestine", "Palestine", "Palestine", "Palestine",
        # Sudan
        "Sudan", "Sudan", "Sudan", "Sudan",
        # Bengal/Myanmar
        "Bengal/Myanmar", "Bengal/Myanmar", "Bengal/Myanmar", "Bengal/Myanmar",
        # Sahel
        "Sahel", "Sahel", "Sahel", "Sahel",
        # Swahili Coast / Somalia
        "Swahili/Somalia", "Swahili/Somalia", "Swahili/Somalia", "Swahili/Somalia"
    ],
    "Species": [
        # Palestine
        "Olive (Olea europaea)",
        "Chickpea (Cicer arietinum)",
        "Moringa peregrina",
        "Goat (Capra hircus)",
        # Sudan
        "Sorghum (Sorghum bicolor)",
        "Baobab (Adansonia digitata)",
        "Groundnut (Arachis hypogaea)",
        "Camel (Camelus dromedarius)",
        # Bengal/Myanmar
        "Rice (Oryza sativa, drought-tolerant landrace)",
        "Pigeon Pea (Cajanus cajan)",
        "Bottle Gourd (Lagenaria siceraria)",
        "Tilapia Fish (Oreochromis niloticus)",
        # Sahel
        "Millet (Pennisetum glaucum)",
        "Cowpea (Vigna unguiculata)",
        "Prickly Pear Cactus (Opuntia ficus-indica)",
        "Sheep (Ovis aries)",
        # Swahili Coast / Somalia
        "Cassava (Manihot esculenta)",
        "Sesame (Sesamum indicum)",
        "Moringa oleifera",
        "Zebu Cattle (Bos indicus)"
    ],
    "Function": [
        # Palestine
        "Perennial oil/tree crop; erosion control; shade & moisture buffer",
        "Nitrogen-fixing pulse; dryland compatible; low-input",
        "Edible leaves; water filtration; drought resilient",
        "Browsers that recycle shrubs and olive waste into manure; hardy on dry slopes",
        # Sudan
        "Main cereal; ridge-compatible; residue for fodder and mulch",
        "Tree for shade, leaves, and vitamin-rich fruit; water retention support",
        "Legume improving soil fertility; compatible with tied-ridge sorghum systems",
        "Manure source; used for milk and dryland traction; minimal water footprint",
        # Bengal/Myanmar
        "Main wetland crop; adapted to monsoon; water synergy with fish ponds",
        "Legume for intercropping with rice and maize; nitrogen fixer",
        "Climbing crop for vertical integration; water-efficient",
        "Used in integrated aquaculture; effluent enriches soil and crops",
        # Sahel
        "Staple grain for sandy soils; deep-rooted drought tolerance",
        "Legume groundcover that retains soil moisture and nitrogen",
        "Cactus used as live fence, fodder, and emergency water/food",
        "Grazing and manure cycling for nutrient input; drought-adapted breeds",
        # Swahili Coast / Somalia
        "Drought-tolerant staple; grows in sandy coastal soils",
        "Oilseed with low water demand; adds diversity and income",
        "Tree with edible pods and leaves; greywater tolerant",
        "Cattle used for mixed farming; manure enriches ridged plots"
    ],
    "System_Role": [
        # Palestine
        "Base layer for dry permaculture terraces",
        "Soil improvement & protein crop",
        "Multi-purpose tree; biofilter & food",
        "Livestock manure & browsing for ecosystem cycling",
        # Sudan
        "Staple crop for ridge moisture capture",
        "Shade & nutrient stabilizer tree",
        "Soil nitrogen addition & intercrop stabilizer",
        "Low water-use livestock for manure input",
        # Bengal/Myanmar
        "Aquatic staple linked to fish systems",
        "Nitrogen fixer for rainfed plots",
        "Vertical space & humidity regulator",
        "Water-soil nutrient loop; mineral enrichment",
        # Sahel
        "Dryland grain integrated with runoff ridges",
        "Legume for sand stabilization & fertility",
        "Fodder, water retention & bio-fence",
        "Organic fertilizer and animal traction",
        # Swahili Coast / Somalia
        "Root crop with high caloric yield under stress",
        "Cash crop for oil and pollinator support",
        "Drought tree for nutrient retention and shade",
        "Integrated livestock nutrient return system"
    ]
}

df = pd.DataFrame(data)

# Display dataset
print("Integrated Agroecological Dataset for In-Situ Systems:")
df
# Out:
# Integrated Agroecological Dataset for In-Situ Systems:
#              Region                                         Species  \
# 0         Palestine                           Olive (Olea europaea)
# 1         Palestine                      Chickpea (Cicer arietinum)
# 2         Palestine                               Moringa peregrina
# 3         Palestine                             Goat (Capra hircus)
# 4             Sudan                       Sorghum (Sorghum bicolor)
# 5             Sudan                     Baobab (Adansonia digitata)
# 6             Sudan                    Groundnut (Arachis hypogaea)
# 7             Sudan                     Camel (Camelus dromedarius)
# 8    Bengal/Myanmar  Rice (Oryza sativa, drought-tolerant landrace)
# 9    Bengal/Myanmar                      Pigeon Pea (Cajanus cajan)
# 10   Bengal/Myanmar              Bottle Gourd (Lagenaria siceraria)
# 11   Bengal/Myanmar            Tilapia Fish (Oreochromis niloticus)
# ...

# %%
# In-situ Agro-Ecological Planning Model
# Author: Bismillah Initiative / Research Collaboration
# Purpose: Generate preliminary intervention outlines for semi-arid and tropical regions
# Regions: Palestine, Sudan, Bengal/Myanmar, Sahel, Swahili Coast, Somalia
# -----------------------
# Step 1. Define regional data
# -----------------------

data = {
    "Region": [
        "Palestine", "Sudan", "Bengal/Myanmar", "Sahel", "Swahili Coast", "Somalia"
    ],
    "PrimaryCrops": [
        "Olives, Chickpeas, Barley, Lentils, Fig, Moringa",
        "Sorghum, Millet, Groundnut, Sesame, Baobab",
        "Rice, Jute, Lentil, Banana, Moringa",
        "Millet, Cowpea, Groundnut, Sorghum, Acacia",
        "Cassava, Coconut, Banana, Legumes, Mango",
        "Sorghum, Maize, Cowpea, Cactus Pear, Moringa"
    ],
    "Livestock": [
        "Sheep, Goats, Bees, Poultry",
        "Cattle, Goats, Camels",
        "Fish, Ducks, Goats",
        "Goats, Sheep, Camels",
        "Goats, Cattle, Poultry, Fish",
        "Camels, Goats, Sheep"
    ],
    "WaterStress": [0.8, 0.9, 0.5, 0.85, 0.6, 0.95],  # 0–1 scale (1 = very dry)
    "SoilFertility": [0.5, 0.45, 0.7, 0.4, 0.55, 0.35],
    "Accessibility": [0.6, 0.5, 0.65, 0.4, 0.55, 0.45]  # 1 = easy logistics
}

df = pd.DataFrame(data)

# -----------------------
# Step 2. Synthetic Labels (Training Target)
# -----------------------

# Labels = "Intervention Type"
labels = [
    "Tied Ridge + Legume Integration",
    "Tied Ridge + Baobab-Moringa Agroforestry",
    "Floating Rice Beds + Duck Integration",
    "Contour Bunds + Groundnut Intercrop",
    "Coconut-Pigeon Pea Agroforestry + Mulching",
    "Cactus-Moringa Fodder + Sand Filter Water Harvest"
]

df["Label"] = labels

# -----------------------
# Step 3. Encode and Train Model
# -----------------------

X = df[["WaterStress", "SoilFertility", "Accessibility"]]
y = df["Label"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model = RandomForestClassifier(random_state=42, n_estimators=50)
model.fit(X_train, y_train)

# Evaluate
y_pred = model.predict(X_test)
report = classification_report(y_test, y_pred, output_dict=True)

# -----------------------
# Step 4. Generate Recommendations
# -----------------------

def make_plan(row):
    if row["WaterStress"] > 0.8:
        water_method = "Tied Ridge / Cactus-based filtration"
    elif row["WaterStress"] > 0.6:
        water_method = "Contour Bunds / In-situ harvesting"
    else:
        water_method = "Rainfed / Pond storage"

    if row["SoilFertility"] < 0.5:
        soil_method = "Legume Rotation + Compost + Fish Waste"
    else:
        soil_method = "Mulch + Crop Residue Integration"

    note = f"Combine {water_method} with {soil_method} and local livestock manure reuse."

    return note

df["RecommendedPlan"] = df.apply(make_plan, axis=1)
df["Predicted_Intervention"] = model.predict(X)

# -----------------------
# Step 5. Output Results
# -----------------------

df.to_csv("region_plans.csv", index=False)

# Save model weaknesses
weakness_text = """
# Model Weaknesses and Recommendations

**1. Data Limitations**
- The dataset is small (6 records), synthetic, and lacks measured field variables (soil pH, salinity, rainfall, cost data).
- Limited representation of seasonality and socio-economic diversity.

**2. Model Constraints**
- RandomForest cannot extrapolate unseen environmental conditions.
- Overfitting possible due to tiny dataset.
- Labels (intervention types) are heuristic, not empirically validated.

**3. Improvement Path**
- Collect 50–100 real records per agroecological zone.
- Add dynamic soil-moisture, NDVI, and water-quality indicators.
- Implement participatory validation with local NGOs and farmers.
- Expand to multi-label classification (one region = several possible interventions).
"""

with open("model_weaknesses.md", "w") as f:
    f.write(weakness_text)

# Save report
with open("model_metrics.json", "w") as f:
    json.dump(report, f, indent=4)

print("✅ Model complete. Outputs:")
print("- region_plans.csv")
print("- model_weaknesses.md")
print("- model_metrics.json")
df
# Out:
# ✅ Model complete. Outputs:
# - region_plans.csv
# - model_weaknesses.md
# - model_metrics.json
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
